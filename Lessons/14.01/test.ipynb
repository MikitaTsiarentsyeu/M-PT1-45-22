# %%
3+5*3
# Out:
# 18

# %%
6+7
# Out:
# 13

# %%
x = 14

# %%
x+45
# Out:
# 59

# %% [markdown]
# Some meaningful text

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.linspace(start=-10, stop=10, num=50)
y = numpy.sin(x)

plt.plot(x, y)
plt.show()
